# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import numpy as np
# %matplotlib inline

# %%
# importing the dataset
parse_data = pd.read_excel("Event Business file append 300 vs2.xlsx",index_col="Order Date", parse_dates=True)

# %%
data = pd.read_excel("Event Business file append 300 vs2.xlsx")

# %%
#COMPANY
print(parse_data['COMPANY'].value_counts())
# Out:
# Callan Capital               15
# Foundation Escrow Company    11
# Corporations Division         6
# Brennan Real Estate Group     3
# Skillstorm                    3
# Center Manufacturing Inc      3
# Ferrari of San Diego          2
# Branch Group Inc              2
# Ideahaus                      2
# CWDL CPAs                     2
# Lancer Group                  1
# OFS Laboratories              1
# National Group                1
# Ascot Shop                    1
# Rady Children's Hospital      1
# Vox DJS                       1
# Lab Corp                      1
# Attention Inc                 1
# The Centers                   1
# Name: COMPANY, dtype: int64

# %%
# Gender distribution
sns.set(style="darkgrid")
sns.countplot(parse_data['GENDER'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# number of the "STANTITLE"
print(parse_data['STANTITLE'].value_counts())
# Out:
# President                  16
# Office Manager             11
# Chief Executive Officer     7
# Owner                       5
# Library Professional        4
# Other Contacts              3
# Manager                     3
# Executive Officer           2
# General Manager             2
# Partner                     2
# Director                    1
# Other Chief Officers        1
# Sales Executive             1
# Name: STANTITLE, dtype: int64

# %%
# Gender distribution
plt.figure(figsize=(22,9))
#sns.set(style="darkgrid")
sns.countplot(parse_data['STANTITLE'], saturation=0.9)
plt.title('STANTITLE')
plt.xlabel('Title')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#PCITY numbers
print(parse_data['PCITY'].value_counts())
# Out:
# La Jolla       20
# San Diego      19
# Springfield     7
# Del Mar         2
# Roanoke         2
# Torrance        1
# Providence      1
# Ocala           1
# Norcross        1
# Fort Myers      1
# Templeton       1
# New Orleans     1
# Centennial      1
# Name: PCITY, dtype: int64

# %%
# PCITY
plt.figure(figsize=(22,9))
#sns.set(style="darkgrid")
sns.countplot(parse_data['PCITY'], saturation=0.9)
plt.title('PCITY')
plt.xlabel('City')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Registration/Ticket Type
print(parse_data['Registration/Ticket Type'].value_counts())
# Out:
# VIP Ticket                                           151
# Single Ticket                                        113
# Pre-Sale Ticket - Ends 8.31.18                        11
# NICU Camera System Paddle Raise - $1,000               5
# NICU Camera System Paddle Raise - $500                 4
# Silver Sponsor - 4 VIP Tickets                         3
# Ski-In & Ski-Out In Whistler Auction Item              2
# NICU Camera System Paddle Raise - $2,000               2
# NICU Camera System Paddle Raise - $100                 2
# Take Me Out To The Ball Game Auction Item              1
# Making Magical Memories In Mykonos Auction Item        1
# Gold Sponsor - 12 VIP Tickets                          1
# Greek "Pop-Up Dinner & Wine" for 10 Auction Item       1
# San Diego Zen Yoga Package Auction Item                1
# Beach Life Flying & Driving In Style Auction Item      1
# Name: Registration/Ticket Type, dtype: int64

# %%
price = parse_data['Registration/Ticket Price'].value_counts()

# %%
p500 = data[data['Registration/Ticket Price'] == 500]

# %%
d500 = p500['Order Date']
d500.shape
# Out:
# (155,)

# %%
price.to_frame(name=None)
# Out:
#       Registration/Ticket Price
# 500                         155
# 225                          69
# 175                          55
# 1000                          5
# 3000                          3
# 2000                          2
# 6500                          2
# 100                           2
# 400                           1
# 5000                          1
# 7500                          1
# 1200                          1
# 1100                          1
# 2100                          1

# %%
ticketPrice = [
    [500, 155],
    [225, 69],
    [175, 55],
    [1000, 5],
    [3000, 3],
    [2000, 2],
    [6500, 2],
    [100, 2],
    [400,1],
    [5000,1],
    [7500,1],
    [1200,1],
    [1100,1],
    [2100,1]
]
name = ["Price", "Count"]
price1 = pd.DataFrame(ticketPrice, columns=name)

# %%
#d1 = data[['Registration/Ticket Price','Order Date']]
#d1

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
plt.figure(figsize=(18,6))
# use the scatter function
plt.scatter(dated.loc['2018-08-04':'2018-08-16'].index, price1['Count'], s=price1['Price']*0.2, alpha=0.5, c=price1['Price'])
plt.show()

# %%
dated.loc['2018-08-04':'2018-08-16'].shape
# Out:
# (14, 78)

# %%
from numpy.random import rand


fig, ax = plt.subplots()
for color in [500,225,175,1000,3000,2000,6500,100,400,5000,7500,1200,1100,2100]:
    ax.scatter(dated.loc['2018-08-04':'2018-08-16'].index, price1['Count'], s=price1['Price']*0.2, alpha=0.5,label=color, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
plt.figure(figsize=(17,5))
dated['Registration/Ticket Price'].plot(linewidth=0.5)

# %% [markdown]
# cols_plot = ['Registration/Ticket Price', 'Registration/Ticket Type', 'STANTITLE']
# axes = dated[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
# for ax in axes:
#     ax.set_ylabel('Daily Totals (GWh)')

# %%
price1['Count'].shape

# %%
ax = dated.loc['2018', 'Registration/Ticket Price'].plot(figsize=(15,5))
ax.set_ylabel('Registration/Ticket Price')
# Out:
# Text(0, 0.5, 'Registration/Ticket Price')

# %%
price1['Count']

# %%
# Registration/Ticket Price distribution
plt.figure(figsize = (16,6))
sns.countplot(parse_data['Registration/Ticket Price'], saturation=0.9)

# %%
# Registration/Ticket Price Distribution
sns.distplot(parse_data['Registration/Ticket Price'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Asef\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Attendee Number of Employees
print(parse_data['Attendee Number of Employees'].value_counts())
# Out:
# 1 - 100      66
# 250 & Up     10
# 100 - 250     1
# Name: Attendee Number of Employees, dtype: int64

# %%
# Attendee Number of Employees
plt.figure(figsize=(10,5))
#sns.set(style="darkgrid")
sns.countplot(parse_data['Attendee Number of Employees'], saturation=0.9)
plt.title('Attendee Number of Employees')
plt.xlabel('Attendee Number of Employees')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Attendee How did you hear about the PEERS Gala?
print(parse_data['Attendee How did you hear about the PEERS Gala?'].value_counts())
# Out:
# Guest of Member                                                                                                                                19
# PEERS Network Member                                                                                                                           17
# PEERS Network Member Friend / Family                                                                                                           15
# Paddle                                                                                                                                         14
# Friend                                                                                                                                         10
# Friends                                                                                                                                         9
# ...

# %%
# date insight
df_1 = parse_data.assign(dayOfweek=parse_data.index.weekday_name).groupby("dayOfweek")["Registration Number"].count()

# %%
df_1
# Out:
# dayOfweek
# Friday       85
# Monday       64
# Saturday     16
# Sunday        9
# Thursday     52
# Tuesday      31
# Wednesday    42
# Name: Registration Number, dtype: int64

# %%
res = [
    ['Friday', 85],
    ['Monday', 64],
    ['Saturday', 16],
    ['Sunday', 9],
    ['Thursday', 52],
    ['Tuesday', 31],
    ['Wednesday', 42]
]

# %%
names = ["Days", "Count"]

# %%
months = pd.DataFrame(res, columns=names)

# %%
months
# Out:
#         Days  Count
# 0     Friday     85
# 1     Monday     64
# 2   Saturday     16
# 3     Sunday      9
# 4   Thursday     52
# 5    Tuesday     31
# 6  Wednesday     42

# %%
months.plot(x="Days", y="Count", kind="bar", legend=True, figsize=(10,5), title="Booking Ordered based on the weekdays")

# %%
# data insight using "month"
df_2 = parse_data.assign(month=parse_data.index.month).groupby(["month"])["Registration Number"].count()

# %%
df_2
# Out:
# month
# 8      62
# 9     217
# 10     18
# 11      2
# Name: Registration Number, dtype: int64

# %%
df_2.plot(kind="bar", title="Booking Order based on the month", figsize=(10,5))

# %%
#PADD1
print(parse_data['PADD1'].value_counts())
# Out:
# 1250 Prospect St Ste 1                12
# 1660 Hotel Cir N Ste 716              10
# 501 S 2nd St                           4
# 6933 S Revere Pkwy Unit B              4
# 4611 Mercury St                        2
# 443 Rutherford Ave NE                  1
# 7938 Ivanhoe Ave                       1
# 1251 Prospect St Ste 1                 1
# 1015 Stratford Ct                      1
# 7750 Girard Ave                        1
# 10105 Pacific Heights Blvd Ste 130     1
# 5664 SW 60th Ave                       1
# 2988 Columbia St                       1
# 888 Prospect St Ste 120                1
# 442 Rutherford Ave NE                  1
# 5152 Murphy Canyon Rd Ste 135          1
# 350 Posada Ln Ste 100                  1
# 7940 Ivanhoe Ave                       1
# 1252 Prospect St Ste 1                 1
# 3020 Childrens Way                     1
# 1014 Stratford Ct                      1
# 2215 Winkler Ave Ste I                 1
# 818 Connecticut Ave Nw Ste 1100        1
# ...

# %%
#finding the unique addresses
uniqueadd = parse_data["PADD1"].unique()

# %%
# there are 32 unique addresses
uniqueadd.shape
# Out:
# (32,)

# %% [markdown]
# ### the distance between "1250 Prospect St Ste 1" and "1660 Hotel Cir N Ste 716" is 10 miles

# %%
#PST
print(parse_data['PST'].value_counts())
# Out:
# CA    43
# CO     5
# IL     4
# VA     2
# GA     1
# LA     1
# FL     1
# RI     1
# Name: PST, dtype: int64

# %%
plt.figure(figsize=(10,5))
#sns.set(style="darkgrid")
sns.countplot(parse_data['PST'], saturation=0.9)
plt.title('PSTATE')
plt.xlabel('States')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# plot
#plt.scatter(data['Order Date'], y=data['Registration/Ticket Type'], c=data['Registration/Ticket Type'], cmap="PuOr", alpha=0.4, edgecolors="grey", linewidth=2)
 
# reverse. Just load the seaborn library for a nice looking appearance.
#import seaborn as sns
#plt.scatter(x, y, s=z*2000, c=x, cmap="PuOr_r", alpha=0.4, edgecolors="grey", linewidth=2)

# %%
#data["Order Date"]

# %%
dated = parse_data.copy()

# %%
# Add columns with year, month, and weekday name
dated['Year'] = dated.index.year
dated['Month'] = dated.index.month
dated['Weekday Name'] = dated.index.weekday_name

# Display a random sampling of 5 rows
dated.sample(5, random_state=0)
# Out:
#                             COMPANY FIRST    LAST GENDER  STANTITLE  \
# Order Date
# 2018-09-14 21:55:00             NaN   NaN     NaN    NaN        NaN
# 2018-08-21 09:46:00             NaN   NaN     NaN    NaN        NaN
# 2018-09-12 15:00:00  Callan Capital   Tim  Callan      M  President
# 2018-09-27 09:25:00             NaN   NaN     NaN    NaN        NaN
# 2018-09-24 13:35:00             NaN   NaN     NaN    NaN        NaN
#
#                     SOURCETITL                   PADD1     PCITY  PST  \
# Order Date
# 2018-09-14 21:55:00        NaN                     NaN       NaN  NaN
# 2018-08-21 09:46:00        NaN                     NaN       NaN  NaN
# 2018-09-12 15:00:00  President  1250 Prospect St Ste 1  La Jolla   CA
# 2018-09-27 09:25:00        NaN                     NaN       NaN  NaN
# 2018-09-24 13:35:00        NaN                     NaN       NaN  NaN
#
#                            PZIP      ...       Transaction Location Insurance  \
# ...
